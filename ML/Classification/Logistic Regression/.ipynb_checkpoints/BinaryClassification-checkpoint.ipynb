# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load the Dataset

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# ### splitting data into x and y

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x.shape, y.shape
# Out:
# ((1025, 13), (1025,))

# %% [markdown]
# ### split data into train and test

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %% [markdown]
# ### Applying Logistic Regresssion model

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# C:\Users\Nikhil Vishwakarma\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred[:5]
# Out:
# array([0, 1, 0, 0, 1], dtype=int64)

# %% [markdown]
# ### Evaluating Model

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score

# %%
y_pred1 = model.predict(x_train)

# %%
print("train dataset accuracy score:",accuracy_score(y_train,y_pred1))
print("test dataset accuracy score:",accuracy_score(y_test,y_pred))
# Out:
# train dataset accuracy score: 0.8585365853658536
# test dataset accuracy score: 0.8439024390243902

# %%
print("train dataset f1 score:",f1_score(y_train,y_pred1))
print("test dataset f1 score:",f1_score(y_test,y_pred))
# Out:
# train dataset f1 score: 0.8699551569506726
# test dataset f1 score: 0.8504672897196262

# %%
cm = confusion_matrix(y_true=y_train,y_pred=y_pred1)

# %%
cm
# Out:
# array([[316,  78],
#        [ 38, 388]], dtype=int64)

# %%
pd.DataFrame(cm)
# Out:
#      0    1
# 0  316   78
# 1   38  388

# %%
sns.heatmap(cm, annot=True, fmt='d', xticklabels=['no disease','disease'], yticklabels=['no disease','disease'])
plt.xlabel('actual value')
plt.ylabel('predicted value')
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_train,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84       394
#            1       0.83      0.91      0.87       426
#
#     accuracy                           0.86       820
#    macro avg       0.86      0.86      0.86       820
# weighted avg       0.86      0.86      0.86       820
